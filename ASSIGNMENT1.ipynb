# %% [raw]
# 1. write a program to check whether two characters entered by the user are the same or different.

# %%
string1 = str(input("enter a FIRST character"))
string2 = str(input("enter a second character"))
if string1 == string2:
    print("both character are same")
else:
    print("character are different")
# Out:
# enter a FIRST character q
# enter a second character q
# both character are same

# %%
string1 = str(input("enter a FIRST character"))
string2 = str(input("enter a second character"))
if string1 == string2:
    print("both character are same")
else:
    print("character are different")
# Out:
# enter a FIRST character a
# enter a second character k
# character are different

# %% [raw]
# 2.write a program to check whether a number is divisible by 7 but not by 5.

# %%
user = int(input("enter a number"))
if user % 7:
    print("a number is divisible by 7")
else:
     print("a number is not divisible by 5")
# Out:
# enter a number 842391
# a number is divisible by 7

# %%
user = int(input("enter a number"))
if user % 7 !=5:
    print("a number is divisible by 7")
else:
     print("a number is not divisible by 5")
# Out:
# enter a number 236
# a number is not divisible by 5

# %% [raw]
# 3. write a program to take two numbers and print whether their sum is even or odd.

# %%
user1 = int(input("enter a 1 number"))
user2 = int(input("enter a 2 number"))
user3 = user1 + user2
if user3 %2 == 0:
    print("enter a number is even")
elif user3 %2 !=0:
    print("enter a nummber is odd")
# Out:
# enter a 1 number 09
# enter a 2 number 34
# enter a nummber is odd

# %% [raw]
# 4. write a program to check whether the sum of two numbers is greather than their product.

# %%
user1 = int(input("enter a first number"))
user2 = int(input("enter a second number"))
user3 = user1 + user2
if user3 > user1: 
    print("enter a number is greather than their product")
else:
    ("enter a number is equal")
# Out:
# enter a first number 2178
# enter a second number 908
# enter a number is greather than their product

# %% [raw]
# 5. write a program to check whether a person is eligible to donate blood (age > 18 and weight >50 kg).

# %%
user1= int(input("enter your age"))
user2 = int(input("enter your weight"))
if user1 >= 18 or user2 >50:
    print("you are eligible to donate blood")
else:
    print("you are not eligible to donate blood")
# Out:
# enter your age 20
# enter your weight 55
# you are eligible to donate blood

# %%
user1= int(input("enter your age"))
user2 = int(input("enter your weight"))
if user1 >= 18 or user2 >= 50:
    print("you are eligible to donate blood")
else:
    print("you are not eligible to donate blood")
# Out:
# enter your age 17
# enter your weight 30
# you are not eligible to donate blood

# %% [raw]
# 6. write a program to check whether a given number is exactly halfwway between two given numbers.

# %%
user1 = int(input("enter a first given number"))
user2 = int(input("enter a second given number"))
user3 = 0
if user1 + user2 and user3 /2:
    print("enter a number is exactly halfway between two given number")
else:
    print("enter a number is not exactly halfway between two given number")
# Out:
# enter a first given number 10
# enter a second given number 20
# enter a number is not exactly halfway between two given number

# %% [raw]
# 7. write a program to check whether marks in maths science and english are all above 40.

# %%
user1 = int(input("enter your math score"))
user2 = int(input("enter your science score"))
user3 = int(input("enter your english score"))
if user1 > 40 and user2 > 40 or user3 > 40:
    print("you are pass")
else:
    print("you are faill")
# Out:
# enter your math score 42
# enter your science score 46
# enter your english score 55
# you are pass

# %% [raw]
# 8. write a program to check loan eligibility based on salary and credit score condition.

# %%
user1 = int(input("enter your salary"))
user2 = int(input("enter your credit score"))
if user1 >= 80000 and user2 >= 800:
    print("you are eligibil for loan")
elif user1 <= 80000 and user2 <= 800:
    print ("you are not eligibil for loan")
# Out:
# enter your salary 88000
# enter your credit score 805
# you are eligibil for loan

# %%
user1 = int(input("enter your salary"))
user2 = int(input("enter your credit score"))
if user1 >= 80000 and user2 >= 800:
    print("you are eligibil for loan")
elif user1 <= 80000 and user2 <= 800:
    print ("you are not eligibil for loan")
# Out:
# enter your salary 75000
# enter your credit score 750
# you are not eligibil for loan

# %% [raw]
# 9. given attendance (%) and assignment - submission flag (y/n) print "allowed" only if attendance >= 75 and submission =="y".

# %%
attendance = int(input("enter your attendance"))
submission = int(input("all sumission are done"))
if attendance >75 and submission != 'y':
    print("you are  eligible for the bord exam")
# Out:
# enter your attendance 90
# all sumission are done 5
# you are  eligible for the bord exam

# %% [raw]
# 10. given hours parked (integer): 0-2 20 , 3-5 50 , 6-10 100, >10 200 print fee.

# %%
user1 = int(input("enter your hours"))
if user1 <=2:
    print("your fee is 20 rupees")
elif user1 <= 5:
    print("your fee is 50 rupees")
elif user1 <=10:
    print("your fee is 100 rupees")
elif user1 >=10:
    print("your fee is 200 rupees")
# Out:
# enter your hours 9
# your fee is 100 rupees

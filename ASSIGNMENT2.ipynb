# %% [raw]
# ## TYPE CONVERSION ASSIGNMENT
# 1. A =65 convert it into float int and string

# %%
A = 65
print(A)
print(type(A))
# Out:
# 65
# <class 'int'>

# %%
 a = 65
print(float(a))
print(type(a))
# Out:
# 65.0
# <class 'int'>

# %%
A = 65
print(str(A))
print(type(A))
# Out:
# 65
# <class 'int'>

# %% [raw]
# 2. b= 100000.45 convert into int and string.

# %%
B = 100000.45
print(int(B))
# Out:
# 100000

# %%
B = 100000.45
print(str(B))
print(type(B))
# Out:
# 100000.45
# <class 'float'>

# %% [raw]
# 3. c= "534423" convert into int and flot

# %%
C= "534423"
print(int(C))
# Out:
# 534423

# %%
C = "534423"
print(float(C))
# Out:
# 534423.0

# %% [raw]
# 4.d= "Welcome to python" convert it into list tuple set

# %%
D = "Welcome to python"
print(list(D))
# Out:
# ['W', 'e', 'l', 'c', 'o', 'm', 'e', ' ', 't', 'o', ' ', 'p', 'y', 't', 'h', 'o', 'n']

# %%
D = "welcome to python"
print(tuple(D))
# Out:
# ('w', 'e', 'l', 'c', 'o', 'm', 'e', ' ', 't', 'o', ' ', 'p', 'y', 't', 'h', 'o', 'n')

# %%
D = "welcome to python"
print(set(D))
# Out:
# {'y', 'o', 'm', 'h', 't', 'l', 'c', 'p', 'n', 'e', 'w', ' '}

# %% [raw]
# 5. take a list of colours and convert it into tuple and set.

# %%
colours = ['red', 'white ', 'black' , 'pink ',' voilt' ,' brown']
print(tuple(colours))
# Out:
# ('red', 'white ', 'black', 'pink ', ' voilt', ' brown')

# %%
print(set(colours))
# Out:
# {' voilt', 'red', ' brown', 'white ', 'black', 'pink '}

# %% [raw]
# 6. take a set of even numbers and convert it into list and tuple

# %%
A = { 2, 4, 6, 8, 10 }
print(list(A))
# Out:
# [2, 4, 6, 8, 10]

# %%
print(tuple(A))
# Out:
# (2, 4, 6, 8, 10)

# %%
def add ():0
A = int(input("Enter a number"))
B = int(input("enter a number"))
print(A+B)
add()
# Out:
# Enter a number 10
# enter a number 7
# 17

# %%
def add (X,Y):
 return X+Y
add(5,5)
# Out:
# 10

# %% [markdown]
# 1. write different functions for multiplication, substraction, division.

# %%
def mul (A,B):
 return A*B
mul(5,5)
# Out:
# 25

# %%
def mul ():0
A = int(input("Enter a number"))
B = int(input("Enter a number"))
print(A*B)
mul()
# Out:
# Enter a number 10
# Enter a number 7
# 70

# %%
def sub (A,B):
    return A-B
sub(5,5)
# Out:
# 0

# %%
def sub ():0
A = int(input("Enter a number"))
B = int(input("Enter a number"))
print(A-B)
sub()
# Out:
# Enter a number 10
# Enter a number 7
# 3

# %%
def div (A,B):
    return A%B
div(5,5)
# Out:
# 0

# %%
def div ():0
A = int(input("Enter a number"))
B = int(input("Enter a number"))
print(A % B)
div()
# Out:
# Enter a number 10
# Enter a number 7
# 3

# %% [markdown]
# 2. write a function which will accept 2 numbers from user and return their division, floor division, modulus.

# %%
def div ():0
X = int(input("Enter a number"))
Y = int(input("Enter a number"))
print(X%Y)
div()
# Out:
# Enter a number 5
# Enter a number 7
# 5

# %%
print(X // Y)
div()
# Out:
# 0

# %%
print(X / Y)
div()
# Out:
# 0.7142857142857143

# %% [markdown]
# 3. write a function to find area of rectangle.

# %% [raw]
# A = L * W

# %%
def Area ():0
X = int(input("Enter a lenght"))
Y = int(input("Enter a width"))
print(X*Y)
Area()
# Out:
# Enter a lenght 10
# Enter a width 20
# 200

# %% [markdown]
# 4. write a function to find area of circle.

# %% [raw]
# area = pi * r^2
# r = d/2
# d = 2*r

# %%
def circle ():0
A = int(input(" Enter a Radius of circule"))
area = 3.14 *(A **2)
print(area)

   
circle()
# Out:
#  Enter a Radius of circule 25
# 1962.5

# %% [markdown]
# 5. write a function to find even and odd numbers,take as user input.

# %%
def user ():0
A = int(input("enter a number"))
if A % 2 == 0:
    print(A, "it is a even number")
else:
    print(A,"it is a odd number")
user()
# Out:
# enter a number 8
# 8 it is a even number

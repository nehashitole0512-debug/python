# %% [markdown]
# 1. write a function add(a,b) and call it using positional arguments.

# %%
def add (a,b):
    return a + b
## calling function using positional arguments
result = add(2,5)
print(result)
# Out:
# 7

# %% [markdown]
# 2. write a function multiply(x,y)and call it using keyword arguments.

# %%
def mul (x,y):
    return x * y
## calling function using keyword arguments
result = mul(x = 5, y = 2)
print(result)
# Out:
# 10

# %% [markdown]
# 3. write a function student(name,age) and call it using positional and keyword arguments.

# %%
def student(name,age):
    print("Name =",name)
    print("Age =",age)
## calling using positional arguments
print("positional argument is")
student("Neha",24)
## calling using keyword arguments
print("keyword argument is")
student(age=24,name ="Neha")
# Out:
# positional argument is
# Name = Neha
# Age = 24
# keyword argument is
# Name = Neha
# Age = 24

# %% [markdown]
# 4. write a function subtract(a,b) and show different outputs by changing argument position.

# %%
def sub(a,b):
    return a - b
## calling keyword argument
subtract =sub(a=5,b=2)
print(subtract)
## using different position
subtract =sub(a = 2,b = 5)
print(subtract)
# Out:
# 3
# -3

# %% [markdown]
# 5. write a function info(name,city,course)and call it by mixing positional and keyword argument correctly.

# %%
def info(name,city,course):
    print("Name=",name)
    print("City=",city)
    print("Course=",course)
## using positional argument
print("positional argument is =")
information = info("Neha","Pune","E&TC")
print(information)
## using keyword argument
print("keyword argument is =")
information = info(course="E&TC",name= "Neha",city="Pune")
print(information)
# Out:
# positional argument is =
# Name= Neha
# City= Pune
# Course= E&TC
# None
# keyword argument is =
# Name= Neha
# City= Pune
# Course= E&TC
# None

# %% [markdown]
# 6. write a function calculate(a,b,c)and call it using only keyword arguments in random order.

# %%
def calculate(a,b,c):
    return a + b + c
## using keywoord argument
Addition =calculate(c=10, a=5, b=3)
print(Addition)
# Out:
# 18

# %% [markdown]
# 7. write a function rectangle(lenght,width) to print area. call it using positional and keyword arguments.

# %%
def rectangle(lenght,width):
    area = length * width
    print("area of rectangle =",area)
##using positional arguments
rectangle(20,15)
# Out:
# 20
# 15
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 7
#       5     print("area of rectangle =",area)
#       6 ##using positional arguments
# ----> 7 rectangle(20,15)
#
# Cell In[35], line 4, in rectangle(lenght, width)
#       2 print(lenght)
#       3 print(width)
# ----> 4 area = length * width
#       5 print("area of rectangle =",area)
#
# NameError: name 'length' is not defined

# %% [markdown]
# 8. a function greet(first_name, last_name) and call it by swapping order using keyword
# arguments

# %%
def greet(first_name,last_name):
    print(first_name)
    print(last_name)
print("keyword argument =")
greet(last_name = "Shitole",first_name = "Neha")
# Out:
# keyword argument =
# Neha
# Shitole

# %% [markdown]
# 9. Write a function total_marks(m1, m2, m3) and call it using positional and keyword arguments.

# %%
def total_marks(m1,m2,m3):
    total = m1 + m2 + m3
    print("Total marks =", total)
print("using positional argument is")
total_marks(40,45,50)
print("usin keyword argument is")
total_marks(m2=60,m3=77,m1=45)
# Out:
# using positional argument is
# Total marks = 135
# usin keyword argument is
# Total marks = 182

# %% [markdown]
# 10. Write a function employee(name, salary, department) and call it correctly and incorrectly to
# show error

# %%
def employee(name,salary,department):
    print("Name =",name)
    print("Salary =",salary)
    print("Department =",department)
print("Function call it Correctly =")
employee("Neha", 25000, "Credit Department")
print("Function call it incorrectly =")
employee("Neha", 25000)
# Out:
# Function call it Correctly =
# Name = Neha
# Salary = 25000
# Department = Credit Department
# Function call it incorrectly =
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 8
#       6 employee("Neha", 25000, "Credit Department")
#       7 print("Function call it incorrectly =")
# ----> 8 employee("Neha", 25000)
#
# TypeError: employee() missing 1 required positional argument: 'department'

# %% [markdown]
# 11. Write a function power(base, exponent) and call it using positional arguments

# %%
def power(base,exponent):
    result = base ** exponent
    print("Result =",result)
power(10,20)
# Out:
# Result = 100000000000000000000

# %% [markdown]
# 12. Write a function details(name, email, phone) and call it using keyword arguments only

# %%
def details(name,email,phone):
    print("Name=",name)
    print("Email=",email)
    print("phone number = ",phone)
details(name= "Neha", phone= 9423901367,email= "nehashitole0512@gmail.com")
# Out:
# Name= Neha
# Email= nehashitole0512@gmail.com
# phone number =  9423901367

# %% [markdown]
# 13. Write a function average(a, b, c, d) and call it using positional arguments.

# %%
def average(a,b,c,d):
    avg=(a + b + c + d)/4
    print("Total Average of =", avg)
average(45,50,55,65)
# Out:
# Total Average of = 53.75

# %% [markdown]
# 14. Write a function login(username, password) and call it using keyword arguments.

# %%
def login (username,password):
    print("username =",username)
    print("password =",password)
login(username = "Neha@123",password = "Nehashitole@7477")
# Out:
# username = Neha@123
# password = Nehashitole@7477

# %% [markdown]
# 15. Write a function circle(radius, pi) and call it using positional and keyword arguments

# %%
def circle (radius,pi):
    area = radius * pi
    return area
## positional argument is
result_1 = circle(25,3.14)
print(result_1)
## keyword argument is
result_2 = circle(pi=3.14 , radius=45)
print(result_2)
# Out:
# 78.5
# 141.3

# %% [markdown]
# 16. Write a function display(course, duration, fees) and call it by mixing positional and keyword
# arguments

# %%
def display(course,duration,fees):
    print("course =",course)
    print("duration =",duration)
    print("fees =",fees)
display("data analysis",duration = "6 month",fees= 40000)
# Out:
# course = data analysis
# duration = 6 month
# fees = 40000

# %% [markdown]
# 17. Write a function max_of_two(a, b) and call it using positional arguments.

# %%
def max_of_two(a,b):
    if a > b:
        print (a)
    else:
        print(b)
max_of_two(2,1)
# Out:
# 2

# %% [markdown]
# 18. Write a function bill(item, price, quantity) and call it using keyword arguments.

# %%
def bill (item,price,quantity):
    print("Item =",item)
    print("Price =",price)
    print("Quantity =",quantity)
bill(quantity=30,item=30,price=500)
# Out:
# Item = 30
# Price = 500
# Quantity = 30

# %% [markdown]
# 19. Write a function profile(name, age, city) and call it using keyword arguments in different order.

# %%
def profile(name,age,city):
    print("Name = ",name)
    print("Age = ",age)
    print("City = ",city)
profile(age= 25, name= "Neha", city= "PCMC")
# Out:
# Name =  Neha
# Age =  25
# City =  PCMC

# %% [markdown]
# 20. Write a function result(maths, science, english) and call it using positional and keyword
# arguments

# %%
def result (maths,science,english):
    print("MATHS MARK IS = ",maths)
    print("SCIENCE MARK IS = ", science)
    print("ENGLISH MARK IS = ",english)
print( "positional arguments is =")
result(55,67,71)
print("keyword argument is = ")
result(science = 77, english= 88, maths = 90)
# Out:
# positional arguments is =
# MATHS MARK IS =  55
# SCIENCE MARK IS =  67
# ENGLISH MARK IS =  71
# keyword argument is =
# MATHS MARK IS =  90
# SCIENCE MARK IS =  77
# ENGLISH MARK IS =  88
